# %%
# GEO query and DEG analysis script

# Install dependencies if not already installed:
# !pip install GEOparse pandas matplotlib seaborn scipy numpy

import GEOparse
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import seaborn as sns
gse_id = "GSE164805"  # <-- Change GEO Series
gse = GEOparse.get_GEO(geo=gse_id, destdir=".")

print(f"Dataset: {gse_id}")
print(f"Title: {gse.metadata['title'][0]}")
print(f"Samples: {len(gse.gsms)}")
dfs = []
for gsm_name, gsm in gse.gsms.items():
    if gsm.table is not None and "VALUE" in gsm.table.columns:
        df = gsm.table[["ID_REF", "VALUE"]].copy()
        df.rename(columns={"VALUE": gsm_name}, inplace=True)
        dfs.append(df)

expr_df = dfs[0]
for df in dfs[1:]:
    expr_df = expr_df.merge(df, on="ID_REF")

expr_df = expr_df.drop_duplicates(subset="ID_REF")
expr_df.set_index("ID_REF", inplace=True)

print("Expression Matrix Shape:", expr_df.shape)

# Save raw matrix
expr_df.to_csv("expression.csv")
print("✅ Saved: expression.csv")
import numpy as np
import pandas as pd
from scipy.stats import ttest_ind
from statsmodels.stats.multitest import multipletests

n = len(expr_df.columns)
control = expr_df.iloc[:, :n//2]
treated = expr_df.iloc[:, n//2:]

pvals, logFCs, t_stats, avg_exp_values = [], [], [], []

for gene in expr_df.index:
    control_values = control.loc[gene]
    treated_values = treated.loc[gene]

    if control_values.dropna().empty or treated_values.dropna().empty:
        stat, p, logFC, avg_exp = np.nan, np.nan, np.nan, np.nan
    else:
        stat, p = ttest_ind(control_values, treated_values, nan_policy="omit")
        logFC = treated_values.mean() - control_values.mean()
        avg_exp = expr_df.loc[gene].mean()

    t_stats.append(stat)
    pvals.append(p)
    logFCs.append(logFC)
    avg_exp_values.append(avg_exp)

deg_df = pd.DataFrame({
    "Gene": expr_df.index,
    "logFC": logFCs,
    "t": t_stats,
    "Pvalue": pvals,
    "AvgExp": avg_exp_values
})

# Safe log10
deg_df["-log10p"] = -np.log10(deg_df["Pvalue"].replace(0, np.nan))

# Adjust p-values
valid = deg_df["Pvalue"].notna()
if valid.sum() > 1:
    deg_df.loc[valid, "adjPvalue"] = multipletests(deg_df.loc[valid, "Pvalue"], method='fdr_bh')[1]
else:
    deg_df["adjPvalue"] = np.nan

deg_df.to_csv("DEG.csv", index=False)
print("✅ Saved: DEG.csv")
# Out:
# Collecting GEOparse
#   Downloading GEOparse-2.0.4-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from GEOparse) (2.32.4)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.12/dist-packages (from GEOparse) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.21.0->GEOparse) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.21.0->GEOparse) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.21.0->GEOparse) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.21.0->GEOparse) (2026.2.25)
# Downloading GEOparse-2.0.4-py3-none-any.whl (29 kB)
# Installing collected packages: GEOparse
# Successfully installed GEOparse-2.0.4
# 11-Apr-2026 07:51:04 DEBUG utils - Directory . already exists. Skipping.
# DEBUG:GEOparse:Directory . already exists. Skipping.
# 11-Apr-2026 07:51:04 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE164nnn/GSE164805/soft/GSE164805_family.soft.gz to ./GSE164805_family.soft.gz
# INFO:GEOparse:Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE164nnn/GSE164805/soft/GSE164805_family.soft.gz to ./GSE164805_family.soft.gz
# 100%|██████████| 10.0M/10.0M [00:00<00:00, 13.3MB/s]
# 11-Apr-2026 07:51:05 DEBUG downloader - Size validation passed
# DEBUG:GEOparse:Size validation passed
# 11-Apr-2026 07:51:05 DEBUG downloader - Moving /tmp/tmprtumkuxg to /content/GSE164805_family.soft.gz
# DEBUG:GEOparse:Moving /tmp/tmprtumkuxg to /content/GSE164805_family.soft.gz
# 11-Apr-2026 07:51:05 DEBUG downloader - Successfully downloaded ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE164nnn/GSE164805/soft/GSE164805_family.soft.gz
# DEBUG:GEOparse:Successfully downloaded ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE164nnn/GSE164805/soft/GSE164805_family.soft.gz
# 11-Apr-2026 07:51:05 INFO GEOparse - Parsing ./GSE164805_family.soft.gz:
# INFO:GEOparse:Parsing ./GSE164805_family.soft.gz:
# 11-Apr-2026 07:51:05 DEBUG GEOparse - DATABASE: GeoMiame
# DEBUG:GEOparse:DATABASE: GeoMiame
# 11-Apr-2026 07:51:05 DEBUG GEOparse - SERIES: GSE164805
# DEBUG:GEOparse:SERIES: GSE164805
# 11-Apr-2026 07:51:05 DEBUG GEOparse - PLATFORM: GPL26963
# DEBUG:GEOparse:PLATFORM: GPL26963
# 11-Apr-2026 07:51:06 DEBUG GEOparse - SAMPLE: GSM5019817
# DEBUG:GEOparse:SAMPLE: GSM5019817
# 11-Apr-2026 07:51:06 DEBUG GEOparse - SAMPLE: GSM5019818
# DEBUG:GEOparse:SAMPLE: GSM5019818
# 11-Apr-2026 07:51:06 DEBUG GEOparse - SAMPLE: GSM5019819
# DEBUG:GEOparse:SAMPLE: GSM5019819
# 11-Apr-2026 07:51:06 DEBUG GEOparse - SAMPLE: GSM5019820
# DEBUG:GEOparse:SAMPLE: GSM5019820
# 11-Apr-2026 07:51:06 DEBUG GEOparse - SAMPLE: GSM5019821
# DEBUG:GEOparse:SAMPLE: GSM5019821
# 11-Apr-2026 07:51:06 DEBUG GEOparse - SAMPLE: GSM5019822
# DEBUG:GEOparse:SAMPLE: GSM5019822
# 11-Apr-2026 07:51:07 DEBUG GEOparse - SAMPLE: GSM5019823
# DEBUG:GEOparse:SAMPLE: GSM5019823
# 11-Apr-2026 07:51:07 DEBUG GEOparse - SAMPLE: GSM5019824
# DEBUG:GEOparse:SAMPLE: GSM5019824
# 11-Apr-2026 07:51:07 DEBUG GEOparse - SAMPLE: GSM5019825
# DEBUG:GEOparse:SAMPLE: GSM5019825
# 11-Apr-2026 07:51:07 DEBUG GEOparse - SAMPLE: GSM5019826
# DEBUG:GEOparse:SAMPLE: GSM5019826
# 11-Apr-2026 07:51:07 DEBUG GEOparse - SAMPLE: GSM5019827
# DEBUG:GEOparse:SAMPLE: GSM5019827
# 11-Apr-2026 07:51:07 DEBUG GEOparse - SAMPLE: GSM5019828
# DEBUG:GEOparse:SAMPLE: GSM5019828
# 11-Apr-2026 07:51:07 DEBUG GEOparse - SAMPLE: GSM5019829
# DEBUG:GEOparse:SAMPLE: GSM5019829
# 11-Apr-2026 07:51:07 DEBUG GEOparse - SAMPLE: GSM5019830
# DEBUG:GEOparse:SAMPLE: GSM5019830
# 11-Apr-2026 07:51:08 DEBUG GEOparse - SAMPLE: GSM5019831
# DEBUG:GEOparse:SAMPLE: GSM5019831
# Dataset: GSE164805
# Title: The transcriptional profiles of severe COVID-19
# Samples: 15
# Expression Matrix Shape: (60795, 15)
# ✅ Saved: expression.csv
# ✅ Saved: DEG.csv
